# %%
import matplotlib.pyplot as plt
import pandas

# %% [markdown]
# # VTRAID :

# %%
df2 = pandas.read_csv("vtraid.csv", names=["N", "runs", "sizeXruns", "throughput"])

N = df2["N"]
throughput = df2["throughput"]

plt.plot(N, throughput, marker='o')
plt.xscale('log', base=2)  # Use log scale for better visualization
plt.yscale('log')
plt.title('Throughput vs N for Vector Triad Benchmark')
plt.xlabel('N')
plt.ylabel('Throughput (Bytes/Second)')
plt.grid(True)
plt.show()

# %% [markdown]
# # VCOPY

# %%
df2 = pandas.read_csv("vcopy.csv", names=["N", "runs", "sizeXruns", "throughput"])

N = df2["N"]
throughput = df2["throughput"]

plt.plot(N, throughput, marker='o')
plt.xscale('log', base=2)  # Use log scale for better visualization
plt.yscale('log')
plt.title('Throughput vs N for Vector Triad Benchmark')
plt.xlabel('N')
plt.ylabel('Throughput (Bytes/Second)')
plt.grid(True)
plt.show()

# %% [markdown]
# # VSUM

# %%
df2 = pandas.read_csv("vsum.csv", names=["N", "runs", "sizeXruns", "throughput"])

N = df2["N"]
throughput = df2["throughput"]

plt.plot(N, throughput, marker='o')
plt.xscale('log', base=2)  # Use log scale for better visualization
plt.yscale('log')
plt.title('Throughput vs N for Vector Triad Benchmark')
plt.xlabel('N')
plt.ylabel('Throughput (Bytes/Second)')
plt.grid(True)
plt.show()

# %% [markdown]
# # VSCALE

# %%
df2 = pandas.read_csv("vscale.csv", names=["N", "runs", "sizeXruns", "throughput"])

N = df2["N"]
throughput = df2["throughput"]

plt.plot(N, throughput, marker='o')
plt.xscale('log', base=2)  # Use log scale for better visualization
plt.yscale('log')
plt.title('Throughput vs N for Vector Triad Benchmark')
plt.xlabel('N')
plt.ylabel('Throughput (Bytes/Second)')
plt.grid(True)
plt.show()

# %% [markdown]
# # All in One

# %%
# List of file names
file_names = ["vtraid.csv", "vcopy.csv", "vscale.csv", "vsum.csv"]

# Plotting loop
for file_name in file_names:
    df = pd.read_csv(file_name, names=["N", "runs", "sizeXruns", "throughput"])
    N = df["N"]
    throughput = df["throughput"]
    
    plt.plot(N, throughput, label=f'{file_name[:-4]}')  # Use the file name (excluding ".csv") as a label

plt.xscale('log', base=2)  # Use log scale for better visualization
plt.yscale('log')
plt.title('Throughput vs N for Vector Triad Benchmark')
plt.xlabel('N')
plt.ylabel('Throughput (Bytes/Second)')
plt.legend()  # Show legend with file names
plt.grid(True)
plt.show()
